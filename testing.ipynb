# %%
import io
import tempfile
file_path="/home/spencer/Downloads/causes-of-death-in-children-under-5.csv"
with open(file_path,"rb") as f:
    contents=f.read()
final_file=io.BytesIO(contents)
final_file

with tempfile.NamedTemporaryFile(delete=False,suffix=".csv",mode='wb') as tmp:
    tmp.write(final_file.getvalue())
    temp_path=tmp.name

temp_path
# Out:
# '/tmp/tmp1lc09q_l.csv'

# %%
import pandas as pd
pd.read_csv("_io.BytesIO at ]0x7556c2813e70")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv("_io.BytesIO at ]0x7556c2813e70")
#
# File ~/.local/share/virtualenvs/codes-CswL-_vv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

model = init_chat_model(
    "Qwen/Qwen2.5-7B-Instruct",
    model_provider="huggingface",
    temperature=0.7,
    max_tokens=1024,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 6
#       2 from langchain.chat_models import init_chat_model
#       4 os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
# ----> 6 model = init_chat_model(
#       7     "Qwen/Qwen2.5-7B-Instruct",
#       8     model_provider="huggingface",
#       9     temperature=0.7,
#      10     max_tokens=1024,
#      11 )
#
# File ~/21s/codes/lexi-agent/lexivenv/lib/python3.12/site-packages/langchain/chat_models/base.py:451, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     443     warnings.warn(
#     444         f"{config_prefix=} has been set but no fields are configurable. Set "
#     445         f"`configurable_fields=(...)` to specify the model params that are "
#     446         f"configurable.",
#     447         stacklevel=2,
# ...

# %%
import os
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

repo_id="meta-llama/Llama-3.1-8B-Instruct"
# repo_id="openai/gpt-oss-20b"

llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    temperature=0.7,
     max_new_tokens=1024,
)
model = ChatHuggingFace(llm=llm)

# %%
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content="Parrots are known for their ability to mimic human speech and other sounds, a trait that has fascinated people for centuries. While we can't know for certain why individual parrots talk, research has provided some insights into the possible reasons behind this behavior:\n\n1. **Social bonding**: In the wild, parrots live in flocks and use vocalizations to communicate with each other. Migrating birds may use mimicry to recognize and locate their flock members. In captivity, parrots may talk to form a bond with their owners or to establish a connection with other birds.\n2. **Attention seeking**: Parrots may talk to get attention from their owners or to initiate interaction. They may associate their vocalizations with positive reinforcement, such as treats or affection.\n3. **Play and learning**: Parrots have been observed to engage in playful vocalizations, such as whistling or screeching, which can be a way for them to learn and practice their vocal skills.\n4. **I
# ...
